# %% [markdown]
# ## Q1. Read the dataset to python environment

# %%
import os
import pandas as pd

pwd=os.getcwd()
df=pd.read_excel(pwd+"/iris_week3.xls")
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Q2. Display the columns in the dataset

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ## Q3. Calculate the mean of each column of the dataset.

# %%
print("The mean of 1st column =",df["SL"].mean())
print("The mean of 2nd column =",df["SW"].mean())
print("The mean of 3rd column =",df["PL"].mean())
print("The mean of 4th column =",df["PW"].mean())
# Out:
# The mean of 1st column = 5.843333333333335
# The mean of 2nd column = 3.0540000000000007
# The mean of 3rd column = 3.7586666666666693
# The mean of 4th column = 1.1986666666666672

# %% [markdown]
# ## Q4. Check for the null values present in the dataset.

# %%
df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ## Q5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# ### BAR GRAPH

# %%
import matplotlib.pyplot as plt
import seaborn as sns

type = df.groupby('Classification')['SL'].mean().to_frame().reset_index()

plt.bar(type['Classification'],type['SL'],color = ['red','green','skyblue']) 

plt.title('Bar Chart')
plt.xlabel('Classification')
plt.ylabel('SepalLength') 
plt.show()

# %% [markdown]
# ### LINE PLOT

# %%
df_values =df.iloc[:,:-1]
columns = df_values.columns
# create x data
x_value = range(0, 150)
# create figure and axis
fig,ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_value, df[column], label=column)
ax.legend()

# %% [markdown]
# ### SCATTER PLOTS

# %%
plt.scatter(df['SL'],df['PL'],alpha=1) 
plt.title('Scatter Plot')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')

plt.show()
